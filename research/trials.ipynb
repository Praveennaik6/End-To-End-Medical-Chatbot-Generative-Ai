# %%
print ("ok")
# Out:
# ok

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Documents\\AI Projects\\End-To-End-Medical-Chatbot-Generative-Ai\\research'

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Documents\\AI Projects\\End-To-End-Medical-Chatbot-Generative-Ai\\research'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from langchain.document_loader import PyPDFLoader, DirectoryLoader
#       2 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain.document_loader'
