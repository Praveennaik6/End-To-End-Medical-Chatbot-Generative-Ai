# %%
print ("ok")
# Out:
# ok

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Documents\\AI Projects\\End-To-End-Medical-Chatbot-Generative-Ai\\research'

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Documents\\AI Projects\\End-To-End-Medical-Chatbot-Generative-Ai\\research'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Documents\\AI Projects'

# %%
os.chdir("End-To-End-Medical-Chatbot-Generative-Ai")

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Documents\\AI Projects\\End-To-End-Medical-Chatbot-Generative-Ai'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
